# %% [markdown]
# <a href="https://colab.research.google.com/github/FlanagG21/DCC-Capstone/blob/main/Embedings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np
from google.colab import files

# %%
#establish connection to google drive - needs to be run from personal account
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/DCC Project/' #change this to match your google drive
# Out:
# Mounted at /content/drive

# %%
# import kaggle movie data
movies = pd.read_csv(file_path + 'cleaned_movies.csv')
songs = pd.read_csv(file_path + 'cleaned_songs.csv')
songs.head()
movies.head()
# Out:
#                                Unique ID  Release Year  \
# 0            Kansas Saloon Smashers-1901        1901.0
# 1     Love by the Light of the Moon-1901        1901.0
# 2           The Martyred Presidents-1901        1901.0
# 3  Terrible Teddy, the Grizzly King-1901        1901.0
# 4            Jack and the Beanstalk-1902        1902.0
#
#                               Title    Genre  \
# 0            Kansas Saloon Smashers  unknown
# 1     Love by the Light of the Moon  unknown
# 2           The Martyred Presidents  unknown
# 3  Terrible Teddy, the Grizzly King  unknown
# 4            Jack and the Beanstalk  unknown
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
lists = movies["Plot"].tolist()
lists.append(songs["lyrics"])
embedings = model.encode(lists)

# %%
np.save('embedings.npy', embedings)
files.download('embedings.npy')
